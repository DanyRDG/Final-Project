# %%
"""
To be sure pip is up to date so the environment can install everything cleanly
"""
# %pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install required libraries for the project
# %pip install -r /files/Final-Project/requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
"""
Adding the project folder to Python's search path so imports work
Downloading and loading datasets
"""
import sys
import importlib

sys.path.append("/files/Final-Project")

import src.data_downloading as dd
importlib.reload(dd)

from src.data_downloading import download_all_data, load_all_data

# Download everything (matches + countries + shootouts)
download_all_data()

# Load them
data = load_all_data()

# Unpack the datasets
matches = data["matches"]      # all_matches.csv
countries = data["countries"]  # countries_names.csv
shootouts = data["shootouts"]  # penalty_shootouts.csv 

# Show dataset shapes to verify everything was loaded correctly
print("Matches:", matches.shape)
print("Countries:", countries.shape if countries is not None else "No countries file")
print("Shootouts:", shootouts.shape if shootouts is not None else "No shootouts file")
# Out:
# ===== DOWNLOADING ALL DATASETS =====
#
# 📦 Main dataset already exists in Final-Project/data/raw
# Penalty shootouts dataset already exists.
#
#  All datasets downloaded successfully!
#
# ✅ Loaded all_matches.csv → 51,013 rows
# ✅ Loaded countries_names.csv → 289 rows
# ✅ Loaded penalty shootouts → 644 rows
# Matches: (51013, 8)
# Countries: (289, 3)
# Shootouts: (644, 5)
